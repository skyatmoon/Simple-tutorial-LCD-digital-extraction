# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
def delete_min_white_area(img, min_area):
    contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[-2:]
    for cnt in contours:
        if cv2.contourArea(cnt) < min_area:
            cv2.drawContours(img, [cnt], 0, 0, -1)
    return img

def delete_min_black_area(img, min_area):
    img_inv = cv2.bitwise_not(img)
    img_inv = delete_min_white_area(img_inv, min_area)
    return cv2.bitwise_not(img_inv)

# %%
img = cv2.imread("/content/Snipaste_2023-03-31_14-37-08.png", 0)
img = cv2.resize(img, (512, 512))
print("01. Grayscale")
cv2_imshow(img)
# Out:
# 01. Grayscale
# <PIL.Image.Image image mode=L size=512x512 at 0x7F727532F7F0>

# %%
bin_mat = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 35, 10)
print("02. Binary")
cv2_imshow(bin_mat)
# Out:
# 02. Binary
# <PIL.Image.Image image mode=L size=512x512 at 0x7F72B1B23DF0>

# %%
element = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
open_mat = cv2.morphologyEx(bin_mat, cv2.MORPH_OPEN, element)

print("03. Opening")
cv2_imshow(open_mat)
# Out:
# 03. Opening
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7283C75C10>

# %%
im1 = delete_min_white_area(open_mat, 50000)

print("04. Remove white noise")
cv2_imshow(im1)
# Out:
# 04. Remove white noise
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7283C752B0>

# %%
im2 = delete_min_black_area(im1, 50000)
print("05. Remove black noise")
cv2_imshow(im2)
# Out:
# 05. Remove black noise
# <PIL.Image.Image image mode=L size=512x512 at 0x7F72B339ADF0>

# %%
element2 = cv2.getStructuringElement(cv2.MORPH_RECT, (51, 51))
im2_close = cv2.morphologyEx(im2, cv2.MORPH_CLOSE, element2)

print("Eliminate main region gaps")
cv2_imshow(im2_close)
# Out:
# Eliminate main region gaps
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7283BB8820>

# %%
ba = cv2.bitwise_and(bin_mat, im2_close)
print("06. Bitwise AND")
cv2_imshow(ba)
# Out:
# 06. Bitwise AND
# <PIL.Image.Image image mode=L size=512x512 at 0x7F72B81BA790>

# %%
element3 = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
ba_close = cv2.morphologyEx(ba, cv2.MORPH_CLOSE, element3)
print("07. Closing")
cv2_imshow(ba_close)
# Out:
# 07. Closing
# <PIL.Image.Image image mode=L size=512x512 at 0x7F72847E0BB0>

# %%
im3 = delete_min_black_area(ba_close, 200)
print("08. Remove black noise after closing")
cv2_imshow(im3)
# Out:
# 08. Remove black noise after closing
# <PIL.Image.Image image mode=L size=512x512 at 0x7F72B1B23FD0>

# %%
element4 = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
im3_open = cv2.morphologyEx(im3, cv2.MORPH_OPEN, element4)
# cv2.imshow("09. Single digit optimization", im3_open)
print("09. Single digit optimization")
cv2_imshow(im3_open)
# Out:
# 09. Single digit optimization
# <PIL.Image.Image image mode=L size=512x512 at 0x7F72753C9580>

# %%
# cv2.imshow("10. Get ROI digit region", im2_close - im3_open)
print("10. Get digit region")
roi = im2_close - im3_open
cv2_imshow(roi)
# Out:
# 10. Get digit region
# <PIL.Image.Image image mode=L size=512x512 at 0x7F72753C9820>

# %%
contours, hierarchy = cv2.findContours(roi, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
for _, c in enumerate(contours):

    boundRect = cv2.boundingRect(c)

    rectX = boundRect[0]
    rectY = boundRect[1]
    rectWidth = boundRect[2]
    rectHeight = boundRect[3]
    # print(rectWidth)
    # print(rectHeight)

    rectArea = rectWidth * rectHeight

    minArea = 5000

    if rectArea > minArea and rectHeight > rectWidth:

        color = (0, 0, 255)
        currentCrop = img[rectY:rectY+rectHeight,rectX:rectX+rectWidth]
        cv2_imshow(currentCrop)
        cv2.rectangle(img, (int(rectX), int(rectY)),
                      (int(rectX + rectWidth), int(rectY + rectHeight)), color, 2)
        cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=69x279 at 0x7F7283BB85B0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7283BB8DF0>
# <PIL.Image.Image image mode=L size=19x272 at 0x7F7283BB8DF0>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7283BB8DF0>
# <PIL.Image.Image image mode=L size=70x280 at 0x7F727533AE50>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F7283C75F70>
# <PIL.Image.Image image mode=L size=63x280 at 0x7F7283C75F70>
# <PIL.Image.Image image mode=L size=512x512 at 0x7F727533AD60>
